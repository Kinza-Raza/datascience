# %%
import pandas as pd
f500=pd.read_csv("f500.csv",index_col=0)
f500
# Out:
#                                               rank  revenues  revenue_change  \
# company
# Walmart                                          1    485873             0.8
# State Grid                                       2    315199            -4.4
# Sinopec Group                                    3    267518            -9.1
# China National Petroleum                         4    262573           -12.3
# Toyota Motor                                     5    254694             7.7
# Volkswagen                                       6    240264             1.5
# Royal Dutch Shell                                7    240033           -11.8
# Berkshire Hathaway                               8    223604             6.1
# Apple                                            9    215639            -7.7
# Exxon Mobil                                     10    205004           -16.7
# McKesson                                        11    198533             3.1
# ...

# %%
f500.index.name=None
f500
# Out:
#                                               rank  revenues  revenue_change  \
# Walmart                                          1    485873             0.8
# State Grid                                       2    315199            -4.4
# Sinopec Group                                    3    267518            -9.1
# China National Petroleum                         4    262573           -12.3
# Toyota Motor                                     5    254694             7.7
# Volkswagen                                       6    240264             1.5
# Royal Dutch Shell                                7    240033           -11.8
# Berkshire Hathaway                               8    223604             6.1
# Apple                                            9    215639            -7.7
# Exxon Mobil                                     10    205004           -16.7
# McKesson                                        11    198533             3.1
# ...

# %%
f500.head(10)
# Out:
#                           rank  revenues  revenue_change  profits  assets  \
# Walmart                      1    485873             0.8  13643.0  198825
# State Grid                   2    315199            -4.4   9571.3  489838
# Sinopec Group                3    267518            -9.1   1257.9  310726
# China National Petroleum     4    262573           -12.3   1867.5  585619
# Toyota Motor                 5    254694             7.7  16899.3  437575
# Volkswagen                   6    240264             1.5   5937.3  432116
# Royal Dutch Shell            7    240033           -11.8   4575.0  411275
# Berkshire Hathaway           8    223604             6.1  24074.0  620854
# Apple                        9    215639            -7.7  45687.0  321686
# Exxon Mobil                 10    205004           -16.7   7840.0  330314
#
#                           profit_change                  ceo  \
# Walmart                            -7.2  C. Douglas McMillon
# ...

# %%
len(f500)
# Out:
# 500

# %%
f500.tail(10)
# Out:
#                                        rank  revenues  revenue_change  \
# National Grid                           491     22036            -3.2
# Dollar General                          492     21987             7.9
# Telecom Italia                          493     21941           -17.4
# Xiamen ITG Holding Group                494     21930            34.3
# Xinjiang Guanghui Industry Investment   495     21919            31.1
# Teva Pharmaceutical Industries          496     21903            11.5
# New China Life Insurance                497     21796           -13.3
# Wm. Morrison Supermarkets               498     21741           -11.3
# TUI                                     499     21655            -5.5
# AutoNation                              500     21609             3.6
#
#                                        profits  assets  profit_change  \
# National Grid                          10150.6   82310          160.2
# ...

# %%
f500.loc[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-333a45c80ac6> in <module>
# ----> 1 f500.loc[0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1910
#    1911         # fall thru to straight lookup
# -> 1912         self._validate_key(key, axis)
#    1913         return self._get_label(key, axis=axis)
#    1914
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1797
#    1798         if not is_list_like_indexer(key):
# ...

# %%
f500["company"]

# %%
import pandas as pd
f5000=pd.read_csv("f500.csv")
f5000
# Out:
#                                           company  rank  revenues  \
# 0                                         Walmart     1    485873
# 1                                      State Grid     2    315199
# 2                                   Sinopec Group     3    267518
# 3                        China National Petroleum     4    262573
# 4                                    Toyota Motor     5    254694
# 5                                      Volkswagen     6    240264
# 6                               Royal Dutch Shell     7    240033
# 7                              Berkshire Hathaway     8    223604
# 8                                           Apple     9    215639
# 9                                     Exxon Mobil    10    205004
# 10                                       McKesson    11    198533
# 11                                             BP    12    186606
# 12                             UnitedHealth Group    13    184840
# ...

# %%
f500["ceo"]["Walmart":"Apple"]
# Out:
# Walmart                     C. Douglas McMillon
# State Grid                              Kou Wei
# Sinopec Group                         Wang Yupu
# China National Petroleum          Zhang Jianhua
# Toyota Motor                        Akio Toyoda
# Volkswagen                      Matthias Muller
# Royal Dutch Shell               Ben van Beurden
# Berkshire Hathaway            Warren E. Buffett
# Apple                           Timothy D. Cook
# Name: ceo, dtype: object

# %%
f500.loc['Toyota Motor']
# Out:
# rank                                                   5
# revenues                                          254694
# revenue_change                                       7.7
# profits                                          16899.3
# assets                                            437575
# profit_change                                      -12.3
# ceo                                          Akio Toyoda
# industry                        Motor Vehicles and Parts
# sector                            Motor Vehicles & Parts
# previous_rank                                          8
# country                                            Japan
# hq_location                                Toyota, Japan
# website                     http://www.toyota-global.com
# years_on_global_500_list                              23
# employees                                         364445
# total_stockholder_equity                          157210
# Name: Toyota Motor, dtype: object

# %%
f500.loc["Walmart":"Apple","ceo":"country"]
# Out:
#                                           ceo  \
# Walmart                   C. Douglas McMillon
# State Grid                            Kou Wei
# Sinopec Group                       Wang Yupu
# China National Petroleum        Zhang Jianhua
# Toyota Motor                      Akio Toyoda
# Volkswagen                    Matthias Muller
# Royal Dutch Shell             Ben van Beurden
# Berkshire Hathaway          Warren E. Buffett
# Apple                         Timothy D. Cook
#
#                                                           industry  \
# Walmart                                      General Merchandisers
# State Grid                                               Utilities
# Sinopec Group                                   Petroleum Refining
# China National Petroleum                        Petroleum Refining
# Toyota Motor                              Motor Vehicles and Parts
# Volkswagen                                Motor Vehicles and Parts
# ...

# %%
data=f500[["ceo","country","profits"]]
data.head()
# Out:
#                                           ceo country  profits
# Walmart                   C. Douglas McMillon     USA  13643.0
# State Grid                            Kou Wei   China   9571.3
# Sinopec Group                       Wang Yupu   China   1257.9
# China National Petroleum        Zhang Jianhua   China   1867.5
# Toyota Motor                      Akio Toyoda   Japan  16899.3

# %%
freq=f500["country"].value_counts()
freq["India"]
# Out:
# 7

# %%
f500.dtypes
# Out:
# rank                          int64
# revenues                      int64
# revenue_change              float64
# profits                     float64
# assets                        int64
# profit_change               float64
# ceo                          object
# industry                     object
# sector                       object
# previous_rank                 int64
# country                      object
# hq_location                  object
# website                      object
# years_on_global_500_list      int64
# employees                     int64
# total_stockholder_equity      int64
# dtype: object

# %%
f5000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 17 columns):
# company                     500 non-null object
# rank                        500 non-null int64
# revenues                    500 non-null int64
# revenue_change              498 non-null float64
# profits                     499 non-null float64
# assets                      500 non-null int64
# profit_change               436 non-null float64
# ceo                         500 non-null object
# industry                    500 non-null object
# sector                      500 non-null object
# previous_rank               500 non-null int64
# country                     500 non-null object
# hq_location                 500 non-null object
# website                     500 non-null object
# years_on_global_500_list    500 non-null int64
# employees                   500 non-null int64
# total_stockholder_equity    500 non-null int64
# dtypes: float64(3), int64(7), object(7)
# ...

# %%
f5000["industry"]
# Out:
# 0                               General Merchandisers
# 1                                           Utilities
# 2                                  Petroleum Refining
# 3                                  Petroleum Refining
# 4                            Motor Vehicles and Parts
# 5                            Motor Vehicles and Parts
# 6                                  Petroleum Refining
# 7            Insurance: Property and Casualty (Stock)
# 8                         Computers, Office Equipment
# 9                                  Petroleum Refining
# 10                           Wholesalers: Health Care
# 11                                 Petroleum Refining
# 12            Health Care: Insurance and Managed Care
# 13           Health Care: Pharmacy and Other Services
# 14                     Electronics, Electrical Equip.
# 15                       Mining, Crude-Oil Production
# 16                           Motor Vehicles and Parts
# ...

# %%
#ranking from usa to india

# %%
import pandas as pd
import numpy as np
f=pd.read_csv("f500.csv")
print(f.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 17 columns):
# company                     500 non-null object
# rank                        500 non-null int64
# revenues                    500 non-null int64
# revenue_change              498 non-null float64
# profits                     499 non-null float64
# assets                      500 non-null int64
# profit_change               436 non-null float64
# ceo                         500 non-null object
# industry                    500 non-null object
# sector                      500 non-null object
# previous_rank               500 non-null int64
# country                     500 non-null object
# hq_location                 500 non-null object
# website                     500 non-null object
# years_on_global_500_list    500 non-null int64
# employees                   500 non-null int64
# total_stockholder_equity    500 non-null int64
# dtypes: float64(3), int64(7), object(7)
# ...

# %%
print(f)
# Out:
#                                           company  rank  revenues  \
# 0                                         Walmart     1    485873
# 1                                      State Grid     2    315199
# 2                                   Sinopec Group     3    267518
# 3                        China National Petroleum     4    262573
# 4                                    Toyota Motor     5    254694
# 5                                      Volkswagen     6    240264
# 6                               Royal Dutch Shell     7    240033
# 7                              Berkshire Hathaway     8    223604
# 8                                           Apple     9    215639
# 9                                     Exxon Mobil    10    205004
# 10                                       McKesson    11    198533
# 11                                             BP    12    186606
# 12                             UnitedHealth Group    13    184840
# ...

# %%
f.loc[0]
# Out:
# company                                    Walmart
# rank                                             1
# revenues                                    485873
# revenue_change                                 0.8
# profits                                      13643
# assets                                      198825
# profit_change                                 -7.2
# ceo                            C. Douglas McMillon
# industry                     General Merchandisers
# sector                                   Retailing
# previous_rank                                    1
# country                                        USA
# hq_location                        Bentonville, AR
# website                     http://www.walmart.com
# years_on_global_500_list                        23
# employees                                  2300000
# total_stockholder_equity                     77798
# Name: 0, dtype: object

# %%
f["company"]
# Out:
# 0                                           Walmart
# 1                                        State Grid
# 2                                     Sinopec Group
# 3                          China National Petroleum
# 4                                      Toyota Motor
# 5                                        Volkswagen
# 6                                 Royal Dutch Shell
# 7                                Berkshire Hathaway
# 8                                             Apple
# 9                                       Exxon Mobil
# 10                                         McKesson
# 11                                               BP
# 12                               UnitedHealth Group
# 13                                       CVS Health
# 14                              Samsung Electronics
# 15                                         Glencore
# 16                                          Daimler
# 17                                   General Motors
# ...

# %%
f["company"]=="Apple"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8       True
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 470    False
# 471    False
# 472    False
# 473    False
# 474    False
# 475    False
# 476    False
# 477    False
# 478    False
# 479    False
# 480    False
# 481    False
# 482    False
# 483    False
# 484    False
# 485    False
# 486    False
# 487    False
# 488    False
# 489    False
# 490    False
# 491    False
# 492    False
# 493    False
# 494    False
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: company, Length: 500, dtype: bool

# %%
f.loc[f["company"]=="Apple"]
# Out:
#   company  rank  revenues  revenue_change  profits  assets  profit_change  \
# 8   Apple     9    215639            -7.7  45687.0  321686          -14.4
#
#                ceo                     industry      sector  previous_rank  \
# 8  Timothy D. Cook  Computers, Office Equipment  Technology              9
#
#   country    hq_location               website  years_on_global_500_list  \
# 8     USA  Cupertino, CA  http://www.apple.com                        15
#
#    employees  total_stockholder_equity
# 8     116000                    128249

# %%
usa=f.loc[f["country"]=="USA",:]

# %%
usa.loc[8]#label ki actual value pr indexing krega
# Out:
# company                                           Apple
# rank                                                  9
# revenues                                         215639
# revenue_change                                     -7.7
# profits                                           45687
# assets                                           321686
# profit_change                                     -14.4
# ceo                                     Timothy D. Cook
# industry                    Computers, Office Equipment
# sector                                       Technology
# previous_rank                                         9
# country                                             USA
# hq_location                               Cupertino, CA
# website                            http://www.apple.com
# years_on_global_500_list                             15
# employees                                        116000
# total_stockholder_equity                         128249
# ...

# %%
usa.iloc[2]#position pr krega
# Out:
# company                                           Apple
# rank                                                  9
# revenues                                         215639
# revenue_change                                     -7.7
# profits                                           45687
# assets                                           321686
# profit_change                                     -14.4
# ceo                                     Timothy D. Cook
# industry                    Computers, Office Equipment
# sector                                       Technology
# previous_rank                                         9
# country                                             USA
# hq_location                               Cupertino, CA
# website                            http://www.apple.com
# years_on_global_500_list                             15
# employees                                        116000
# total_stockholder_equity                         128249
# ...

# %%
f.iloc[0,0]
# Out:
# 'Walmart'

# %%
f.loc["company":"profits"]
# Out:
# Empty DataFrame
# Columns: [company, rank, revenues, revenue_change, profits, assets, profit_change, ceo, industry, sector, previous_rank, country, hq_location, website, years_on_global_500_list, employees, total_stockholder_equity]
# Index: []

# %%
f.loc[:,"company":"profits"]
# Out:
#                                           company  rank  revenues  \
# 0                                         Walmart     1    485873
# 1                                      State Grid     2    315199
# 2                                   Sinopec Group     3    267518
# 3                        China National Petroleum     4    262573
# 4                                    Toyota Motor     5    254694
# 5                                      Volkswagen     6    240264
# 6                               Royal Dutch Shell     7    240033
# 7                              Berkshire Hathaway     8    223604
# 8                                           Apple     9    215639
# 9                                     Exxon Mobil    10    205004
# 10                                       McKesson    11    198533
# 11                                             BP    12    186606
# 12                             UnitedHealth Group    13    184840
# ...

# %%
f.loc[5:9]#slicing of rows
# Out:
#               company  rank  revenues  revenue_change  profits  assets  \
# 5          Volkswagen     6    240264             1.5   5937.3  432116
# 6   Royal Dutch Shell     7    240033           -11.8   4575.0  411275
# 7  Berkshire Hathaway     8    223604             6.1  24074.0  620854
# 8               Apple     9    215639            -7.7  45687.0  321686
# 9         Exxon Mobil    10    205004           -16.7   7840.0  330314
#
#    profit_change                ceo                                  industry  \
# 5            NaN    Matthias Muller                  Motor Vehicles and Parts
# 6          135.9    Ben van Beurden                        Petroleum Refining
# 7            NaN  Warren E. Buffett  Insurance: Property and Casualty (Stock)
# 8          -14.4    Timothy D. Cook               Computers, Office Equipment
# 9          -51.5    Darren W. Woods                        Petroleum Refining
#
# ...

# %%
rankchange=f["previous_rank"]-f["rank"]
rankchange
# Out:
# 0        0
# 1        0
# 2        1
# 3       -1
# 4        3
# 5        1
# 6       -2
# 7        3
# 8        0
# 9       -4
# 10       1
# 11      -2
# 12       4
# 13       4
# 14      -2
# 15      -2
# 16      -1
# 17       2
# 18       4
# 19      -1
# 20       0
# 21      -7
# 22       5
# 23       3
# 24       8
# 25      18
# 26      -2
# 27      -6
# 28       7
# 29      -6
#       ...
# 470     16
# 471    -27
# 472   -473
# 473      9
# 474    -14
# 475    -92
# 476     17
# 477   -478
# 478    -50
# 479     -8
# 480      9
# 481      6
# 482   -483
# 483    -18
# 484   -485
# 485    -55
# 486    -13
# 487   -488
# 488    -64
# 489   -107
# 490    -20
# 491   -492
# 492    -89
# 493   -494
# 494   -495
# 495   -496
# 496    -70
# 497    -61
# 498    -32
# 499   -500
# Length: 500, dtype: int64

# %%
rankchange.describe()#max is the maximum value in our answer
# Out:
# count    500.000000
# mean     -28.366000
# std      108.602823
# min     -500.000000
# 25%      -28.250000
# 50%       -4.000000
# 75%        8.250000
# max      226.000000
# dtype: float64

# %%
type(rankchange)
# Out:
# pandas.core.series.Series

# %%
bol=f["previous_rank"]==0
#f.loc[bol]
f[bol]
# Out:
#                                    company  rank  revenues  revenue_change  \
# 48                   Legal & General Group    49    105235           442.3
# 90                                  Uniper    91     74407             NaN
# 123                      Dell Technologies   124     64806            18.1
# 138                 Anbang Insurance Group   139     60800           124.0
# 140                        Albertsons Cos.   141     59678             1.6
# 180             Hewlett Packard Enterprise   181     50123             NaN
# 267                           Hengli Group   268     37880            12.2
# 271         Johnson Controls International   272     37674            -6.3
# 341                                  Chubb   342     31469            65.7
# 375                 Charter Communications   376     29003           197.3
# 376                              Medtronic   377     28833            42.3
# ...

# %%
f.loc[bol,"previous_rank"]=np.nan

# %%
f["previous_rank"]
# Out:
# 0        1.0
# 1        2.0
# 2        4.0
# 3        3.0
# 4        8.0
# 5        7.0
# 6        5.0
# 7       11.0
# 8        9.0
# 9        6.0
# 10      12.0
# 11      10.0
# 12      17.0
# 13      18.0
# 14      13.0
# 15      14.0
# 16      16.0
# 17      20.0
# 18      23.0
# 19      19.0
# 20      21.0
# 21      15.0
# 22      28.0
# 23      27.0
# 24      33.0
# 25      44.0
# 26      25.0
# 27      22.0
# 28      36.0
# 29      24.0
#        ...
# 470    487.0
# 471    445.0
# 472      NaN
# 473    483.0
# 474    461.0
# 475    384.0
# 476    494.0
# 477      NaN
# 478    429.0
# 479    472.0
# 480    490.0
# 481    488.0
# 482      NaN
# 483    466.0
# 484      NaN
# 485    431.0
# 486    474.0
# 487      NaN
# 488    425.0
# 489    383.0
# 490    471.0
# 491      NaN
# 492    404.0
# 493      NaN
# 494      NaN
# 495      NaN
# 496    427.0
# 497    437.0
# 498    467.0
# 499      NaN
# Name: previous_rank, Length: 500, dtype: float64

# %%
f["previous_rank"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 470    False
# 471    False
# 472     True
# 473    False
# 474    False
# 475    False
# 476    False
# 477     True
# 478    False
# 479    False
# 480    False
# 481    False
# 482     True
# 483    False
# 484     True
# 485    False
# 486    False
# 487     True
# 488    False
# 489    False
# 490    False
# 491     True
# 492    False
# 493     True
# 494     True
# 495     True
# 496    False
# 497    False
# 498    False
# 499     True
# Name: previous_rank, Length: 500, dtype: bool

# %%
z=f["previous_rank"].notnull()
x=f["rank"]
zz=f[z]

b=zz["previous_rank"]
newranks=x-b
newranks
# Out:
# 0        0.0
# 1        0.0
# 2       -1.0
# 3        1.0
# 4       -3.0
# 5       -1.0
# 6        2.0
# 7       -3.0
# 8        0.0
# 9        4.0
# 10      -1.0
# 11       2.0
# 12      -4.0
# 13      -4.0
# 14       2.0
# 15       2.0
# 16       1.0
# 17      -2.0
# 18      -4.0
# 19       1.0
# 20       0.0
# 21       7.0
# 22      -5.0
# 23      -3.0
# 24      -8.0
# 25     -18.0
# 26       2.0
# 27       6.0
# 28      -7.0
# 29       6.0
#        ...
# 470    -16.0
# 471     27.0
# 472      NaN
# 473     -9.0
# 474     14.0
# 475     92.0
# 476    -17.0
# 477      NaN
# 478     50.0
# 479      8.0
# 480     -9.0
# 481     -6.0
# 482      NaN
# 483     18.0
# 484      NaN
# 485     55.0
# 486     13.0
# 487      NaN
# 488     64.0
# 489    107.0
# 490     20.0
# 491      NaN
# 492     89.0
# 493      NaN
# 494      NaN
# 495      NaN
# 496     70.0
# 497     61.0
# 498     32.0
# 499      NaN
# Length: 500, dtype: float64

# %%
newranks.describe()
# Out:
# count    467.000000
# mean       3.533191
# std       44.293603
# min     -226.000000
# 25%      -10.000000
# 50%        2.000000
# 75%       21.000000
# max      199.000000
# dtype: float64

# %%
f["rank_change"]=newranks

# %%
f
# Out:
#                                           company  rank  revenues  \
# 0                                         Walmart     1    485873
# 1                                      State Grid     2    315199
# 2                                   Sinopec Group     3    267518
# 3                        China National Petroleum     4    262573
# 4                                    Toyota Motor     5    254694
# 5                                      Volkswagen     6    240264
# 6                               Royal Dutch Shell     7    240033
# 7                              Berkshire Hathaway     8    223604
# 8                                           Apple     9    215639
# 9                                     Exxon Mobil    10    205004
# 10                                       McKesson    11    198533
# 11                                             BP    12    186606
# 12                             UnitedHealth Group    13    184840
# ...

# %%
usa=f["country"]=='USA'
e=f[usa]
a=e["employees"]

# %%
country=f500["country"].unique()
employee={}
for i in country:
    df=f500[f500["country"]==i]
    df=df.sort_values
