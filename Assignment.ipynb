# %%
import pandas as pd 
import numpy as np 
import sqlite3 as sql 
import matplotlib.pyplot as plt

# %% [markdown]
# Trying to find if number of sales of individual tracks was greater or sales of albums based on available data.

# %%
db = "chinook.db"
conn = sql.connect(db)

# %%
def run(q):
    return pd.read_sql_query(q,conn)

# %%
q = """select name,type from sqlite_master where type='table'"""
run(q)
# Out:
#               name   type
# 0            album  table
# 1           artist  table
# 2         customer  table
# 3         employee  table
# 4            genre  table
# 5          invoice  table
# 6     invoice_line  table
# 7       media_type  table
# 8         playlist  table
# 9   playlist_track  table
# 10           track  table
# 11  wishlist_track  table
# 12        wishlist  table

# %%
q = """select * from album limit 5"""
run(q)
# Out:
#    album_id                                  title  artist_id
# 0         1  For Those About To Rock We Salute You          1
# 1         2                      Balls to the Wall          2
# 2         3                      Restless and Wild          2
# 3         4                      Let There Be Rock          1
# 4         5                               Big Ones          3

# %%
q = """select * from invoice_line where invoice_id=2 """
run(q)
# Out:
#    invoice_line_id  invoice_id  track_id  unit_price  quantity
# 0               17           2      3476        0.99         1
# 1               18           2       482        0.99         1
# 2               19           2      2701        0.99         1
# 3               20           2      1641        0.99         1
# 4               21           2      1119        0.99         1
# 5               22           2      2324        0.99         1
# 6               23           2       201        0.99         1
# 7               24           2       819        0.99         1
# 8               25           2       392        0.99         1
# 9               26           2      2651        0.99         1

# %%
q = """create view tracksinalbums as select album_id,count(track_id) trackid from track group by 1
"""
run(q)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1430             else:
# -> 1431                 cur.execute(*args)
#    1432             return cur
#
# OperationalError: table tracksinalbums already exists
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-14-2b0d20822232> in <module>
#       1 q = """create view tracksinalbums as select album_id,count(track_id) trackid from track group by 1
#       2 """
# ----> 3 run(q)
#
# <ipython-input-10-5ded2084316c> in run(q)
#       1 def run(q):
# ----> 2     return pd.read_sql_query(q,conn)
#
# ...

# %%
#q = """select album_id, track_id from track"""
run(q)

# %%
#number of songs in each album
q = """select * from tracksinalbums"""
tracks_in_albums = run(q)
tracks_in_albums
# Out:
#      album_id  trackid
# 0           1       10
# 1           2        1
# 2           3        3
# 3           4        8
# 4           5       15
# 5           6       13
# 6           7       12
# 7           8       14
# 8           9        8
# 9          10       14
# 10         11       12
# 11         12       12
# 12         13        8
# 13         14       13
# 14         15        5
# 15         16        7
# 16         17       10
# 17         18       17
# 18         19       11
# 19         20       11
# 20         21       18
# 21         22        3
# 22         23       34
# 23         24       23
# 24         25       13
# 25         26       17
# 26         27       14
# 27         28       10
# 28         29       14
# 29         30       14
# ..        ...      ...
# 317       318        1
# 318       319        1
# 319       320        1
# 320       321       12
# 321       322       11
# 322       323        1
# 323       324        1
# 324       325        1
# ...

# %%
q = """select album_id from track where track_id=9"""
run(q)
# Out:
#    album_id
# 0         1

# %%
q = """create view table2 as select t.album_id album_id, inv.invoice_line_id, inv.invoice_id, inv.track_id, inv.quantity
        from track t inner join invoice_line inv on t.track_id = inv.track_id
        """
run(q)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1430             else:
# -> 1431                 cur.execute(*args)
#    1432             return cur
#
# OperationalError: table table2 already exists
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-70-89394b48168e> in <module>
#       2         from track t inner join invoice_line inv on t.track_id = inv.track_id
#       3         """
# ----> 4 run(q)
#
# <ipython-input-10-5ded2084316c> in run(q)
#       1 def run(q):
# ----> 2     return pd.read_sql_query(q,conn)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
# ...

# %%
#table showing all purchases in each invoice
q = """select * from table2"""
query = run(q)
query
# Out:
#       album_id  invoice_line_id  invoice_id  track_id  quantity
# 0           91                1           1      1158         1
# 1           91                2           1      1159         1
# 2           91                3           1      1160         1
# 3           91                4           1      1161         1
# 4           91                5           1      1162         1
# 5           91                6           1      1163         1
# 6           91                7           1      1164         1
# 7           91                8           1      1165         1
# 8           91                9           1      1166         1
# 9           91               10           1      1167         1
# 10          91               11           1      1168         1
# 11          91               12           1      1169         1
# 12          91               13           1      1170         1
# 13          91               14           1      1171         1
# ...

# %%
boolean = query.duplicated(['album_id','invoice_id'],keep=False)
#boolean[171]

# %%
boolean.to_frame()
query["Album purchased"] = boolean
query["Album purchased"].value_counts()
#tracks_in_albums["trackid"]
# Out:
# False    2863
# True     1894
# Name: Album purchased, dtype: int64

# %%
inv = query.groupby("invoice_id")
alb = inv["Album_ID"]
xy = alb.value_counts().to_frame()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-97b675bdd285> in <module>
#       1 inv = query.groupby("invoice_id")
# ----> 2 alb = inv["Album_ID"]
#       3 xy = alb.value_counts().to_frame()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     273         else:
#     274             if key not in self.obj:
# --> 275                 raise KeyError("Column not found: {key}".format(key=key))
#     276             return self._gotitem(key, ndim=1)
#     277
#
# KeyError: 'Column not found: Album_ID'

# %%
#inv.get_group(613)
def func(x,y):
    if x.value_counts() == y
# Out:
#   File "<ipython-input-21-ae00ecb8e364>", line 3
#     if x.value_counts() == y
#                             ^
# SyntaxError: invalid syntax

# %%
pd.concat([tracks_in_albums,xy],join="inner", ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f0fb73e8c959> in <module>
# ----> 1 pd.concat([tracks_in_albums,xy],join="inner", ignore_index = True)
#
# NameError: name 'xy' is not defined

# %%
#q = """with tbl as (select album_id,track_id,count(track_id) "num_of_tracks" from track group by 1)

  #  select t.album_id Album_ID, inv.invoice_line_id, inv.invoice_id, inv.track_id, inv.quantity
    #    from tbl t inner join invoice_line inv on t.track_id = inv.track_id inner join tracksinalbums tia on 
    #    tia.album_id=t.album_id where t.num_of_tracks=tia.trackid
        
   #     """
#run(q)

# %%
q_songs = """create view songs as select album_id, track_id from track """
run(q_songs)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1430             else:
# -> 1431                 cur.execute(*args)
#    1432             return cur
#
# OperationalError: table songs already exists
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-24-e34b367167c1> in <module>
#       1 q_songs = """create view songs as select album_id, track_id from track """
# ----> 2 run(q_songs)
#
# <ipython-input-10-5ded2084316c> in run(q)
#       1 def run(q):
# ----> 2     return pd.read_sql_query(q,conn)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
# ...

# %% [markdown]
# views: tracksinalbums, songs
# temp tables: table1 (join of inv line and track)

# %%
q = """create view xyz as with abc as (select count(track_id) count,Album_id,invoice_id,invoice_line_id from table1 group by 3)
        select a.Album_id,a.invoice_id,a.count from abc a inner join tracksinalbums tia on a.Album_ID=tia.album_id
        where a.count==tia.trackid order by 2
 
"""
run(q)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1430             else:
# -> 1431                 cur.execute(*args)
#    1432             return cur
#
# OperationalError: table xyz already exists
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-123-4db7f3b2cbe9> in <module>
#       4
#       5 """
# ----> 6 run(q)
#
# <ipython-input-10-5ded2084316c> in run(q)
#       1 def run(q):
# ----> 2     return pd.read_sql_query(q,conn)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     312     return pandas_sql.read_query(
# ...

# %%
#list of all albums purchased as a whole
q = """select * from xyz"""
run(q)

# %%
q = """create view tbl2 as with abc as (select count(track_id) count,Album_id,invoice_id,invoice_line_id from table1 group by 3)
        select a.Album_id,a.invoice_id,a.count from abc a inner join tracksinalbums tia on a.Album_ID=tia.album_id 
        where a.count==tia.trackid  order by 2
 
"""
run(q)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1430             else:
# -> 1431                 cur.execute(*args)
#    1432             return cur
#
# OperationalError: table tbl2 already exists
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-29-62357e856b41> in <module>
#       4
#       5 """
# ----> 6 run(q)
#
# <ipython-input-10-5ded2084316c> in run(q)
#       1 def run(q):
# ----> 2     return pd.read_sql_query(q,conn)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     312     return pandas_sql.read_query(
# ...

# %%
q="""select count(invoice_id) albums from xyz"""
albums=run(q)

# %%
q = """select count(distinct(invoice_id)) "total" from invoice_line"""
total=run(q)

# %%
q="""select count(distinct(invoice_id))-(select count(*) from xyz) "tracks" from invoice_line """
tracks=run(q)

# %%
q = """select (select cast(count(distinct(invoice_id))-(select count(*) from xyz) as float) from invoice_line)
/count(distinct(invoice_id))*100 tr_perc from invoice_line """
tr_perc=run(q)

# %%
q="""select 100 - (select cast(count(distinct(invoice_id))-(select count(*) from xyz) as float) from invoice_line)
/count(distinct(invoice_id))*100 alb_perc from invoice_line"""
alb_perc=run(q)

# %%
cols = {'Albums sold':['Yes','No'],'Quantity':[albums["albums"].values[0],tracks["tracks"].values[0]],
        'Percentage':[tr_perc["tr_perc"].values[0],alb_perc["alb_perc"].values[0]]}
df = pd.DataFrame(cols)
df
# Out:
#   Albums sold  Quantity  Percentage
# 0         Yes       122   80.130293
# 1          No       492   19.869707

# %%
x= {'Album_ID':'album_id','invoice_id':'invoice_id','track_id':'track_id'}
df1.columns = df1.columns.map(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-8415445edaae> in <module>
#       1 x= {'Album_ID':'album_id','invoice_id':'invoice_id','track_id':'track_id'}
# ----> 2 df1.columns = df1.columns.map(x)
#
# AttributeError: 'NoneType' object has no attribute 'columns'

# %%
df1
# Out:
#       album_id  invoice_id  track_id
# 0           91           1      1158
# 1           91           1      1159
# 2           91           1      1160
# 3           91           1      1161
# 4           91           1      1162
# 5           91           1      1163
# 6           91           1      1164
# 7           91           1      1165
# 8           91           1      1166
# 9           91           1      1167
# 10          91           1      1168
# 11          91           1      1169
# 12          91           1      1170
# 13          91           1      1171
# 14          91           1      1172
# 15          91           1      1173
# 16         322           2      3476
# 17          39           2       482
# 18         218           2      2701
# 19         134           2      1641
# 20          73           2      1119
# 21         190           2      2324
# 22          20           2       201
# 23          66           2       819
# ...

# %%
q = """select t.invoice_id,t.album_id from table2 t inner join songs s on t.track_id=s.track_id 
        inner join xyz x on x.invoice_id=t.invoice_id inner join tracksinalbums tia on 
        tia.album_id=t.album_id where x.count==tia.trackid & t.track_id not in (s.track_id)
        group by 1
"""
run(q)
# Out:
#      invoice_id  album_id
# 0             1        91
# 1             5       163
# 2             7         6
# 3            23         1
# 4            24        90
# 5            31       221
# 6            32         6
# 7            44       242
# 8            46       214
# 9            52       216
# 10           54       146
# 11           56       185
# 12           61       212
# 13           64         6
# 14           69        10
# 15           71       185
# 16           73       195
# 17           76        82
# 18           79       157
# 19           84       321
# 20           87        88
# 21           90       207
# 22           91        10
# 23           92       115
# 24           99       211
# 25          112       120
# 26          114       120
# 27          123       164
# 28          138       186
# 29          141       213
# ..          ...       ...
# 92          449       120
# 93          457       126
# 94          465        16
# ...

# %%
q = """select * from abc"""
run(q)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1430             else:
# -> 1431                 cur.execute(*args)
#    1432             return cur
#
# OperationalError: no such table: abc
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-121-76eea13e6364> in <module>
#       1 q = """select * from abc"""
# ----> 2 run(q)
#
# <ipython-input-10-5ded2084316c> in run(q)
#       1 def run(q):
# ----> 2     return pd.read_sql_query(q,conn)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     312     return pandas_sql.read_query(
# ...

# %%
albums
# Out:
#    count(invoice_id)
# 0                122
