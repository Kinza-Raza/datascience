# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
hap15=pd.read_csv("World_Happiness_2015.csv")
hap15
hap15['Year']=2015

# %%
hap16=pd.read_csv("World_Happiness_2016.csv")
hap16

hap16['Year']=2016

# %%
hap17=pd.read_csv("World_Happiness_2017.csv")
hap17

hap17['Year']=2017

# %%
print(hap15.columns)
print(hap16.columns)
print(hap17.columns)
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual', 'Year'],
#       dtype='object')
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual', 'Year'],
#       dtype='object')
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual', 'Year'],
#       dtype='object')

# %%
hap17.columns=hap17.columns.str.replace("."," ").str.upper().str.strip()
#hap17.columns
hap17.columns.str.replace("\s+"," ")
#backslash s space ko htane k lie lgaya he
#+ka sign do spaces ko check krega
# Out:
# Index(['COUNTRY', 'HAPPINESS RANK', 'HAPPINESS SCORE', 'WHISKER HIGH',
#        'WHISKER LOW', 'ECONOMY GDP PER CAPITA', 'FAMILY',
#        'HEALTH LIFE EXPECTANCY', 'FREEDOM', 'GENEROSITY',
#        'TRUST GOVERNMENT CORRUPTION', 'DYSTOPIA RESIDUAL', 'YEAR'],
#       dtype='object')

# %%
hap15.columns=hap15.columns.str.replace("."," ").str.upper().str.strip().str.replace("\s+"," ").str.replace("[\(\)]","")
hap15.columns
#backslash islie lgaya he wrna ise ye capturing group consider krega
# Out:
# Index(['COUNTRY', 'REGION', 'HAPPINESS RANK', 'HAPPINESS SCORE',
#        'STANDARD ERROR', 'ECONOMY GDP PER CAPITA', 'FAMILY',
#        'HEALTH LIFE EXPECTANCY', 'FREEDOM', 'TRUST GOVERNMENT CORRUPTION',
#        'GENEROSITY', 'DYSTOPIA RESIDUAL', 'YEAR'],
#       dtype='object')

# %%
hap16.columns=hap16.columns.str.replace("."," ").str.upper().str.strip().str.replace("\s+"," ").str.replace("[\(\)]","")
hap16.columns
# Out:
# Index(['COUNTRY', 'REGION', 'HAPPINESS RANK', 'HAPPINESS SCORE',
#        'LOWER CONFIDENCE INTERVAL', 'UPPER CONFIDENCE INTERVAL',
#        'ECONOMY GDP PER CAPITA', 'FAMILY', 'HEALTH LIFE EXPECTANCY', 'FREEDOM',
#        'TRUST GOVERNMENT CORRUPTION', 'GENEROSITY', 'DYSTOPIA RESIDUAL',
#        'YEAR'],
#       dtype='object')

# %%
combined=pd.concat([hap15,hap16,hap17],axis=0,ignore_index=True, sort=True)

# %%
combined["YEAR"]
# Out:
# 0      2015
# 1      2015
# 2      2015
# 3      2015
# 4      2015
# 5      2015
# 6      2015
# 7      2015
# 8      2015
# 9      2015
# 10     2015
# 11     2015
# 12     2015
# 13     2015
# 14     2015
# 15     2015
# 16     2015
# 17     2015
# 18     2015
# 19     2015
# 20     2015
# 21     2015
# 22     2015
# 23     2015
# 24     2015
# 25     2015
# 26     2015
# 27     2015
# 28     2015
# 29     2015
#        ...
# 440    2017
# 441    2017
# 442    2017
# 443    2017
# 444    2017
# 445    2017
# 446    2017
# 447    2017
# 448    2017
# 449    2017
# 450    2017
# 451    2017
# 452    2017
# 453    2017
# 454    2017
# 455    2017
# 456    2017
# 457    2017
# 458    2017
# 459    2017
# 460    2017
# 461    2017
# 462    2017
# 463    2017
# 464    2017
# 465    2017
# 466    2017
# 467    2017
# 468    2017
# 469    2017
# Name: YEAR, Length: 470, dtype: int64

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 470 entries, 0 to 469
# Data columns (total 20 columns):
# COUNTRY                         470 non-null object
# DYSTOPIA RESIDUAL               470 non-null float64
# ECONOMY  GDP PER CAPITA         155 non-null float64
# ECONOMY GDP PER CAPITA          315 non-null float64
# FAMILY                          470 non-null float64
# FREEDOM                         470 non-null float64
# GENEROSITY                      470 non-null float64
# HAPPINESS RANK                  470 non-null int64
# HAPPINESS SCORE                 470 non-null float64
# HEALTH  LIFE EXPECTANCY         155 non-null float64
# HEALTH LIFE EXPECTANCY          315 non-null float64
# LOWER CONFIDENCE INTERVAL       157 non-null float64
# REGION                          315 non-null object
# STANDARD ERROR                  158 non-null float64
# TRUST  GOVERNMENT CORRUPTION    155 non-null float64
# TRUST GOVERNMENT CORRUPTION     315 non-null float64
# ...

# %%
combined
# Out:
#                       COUNTRY  DYSTOPIA RESIDUAL  ECONOMY  GDP PER CAPITA  \
# 0                 Switzerland           2.517380                      NaN
# 1                     Iceland           2.702010                      NaN
# 2                     Denmark           2.492040                      NaN
# 3                      Norway           2.465310                      NaN
# 4                      Canada           2.451760                      NaN
# 5                     Finland           2.619550                      NaN
# 6                 Netherlands           2.465700                      NaN
# 7                      Sweden           2.371190                      NaN
# 8                 New Zealand           2.264250                      NaN
# 9                   Australia           2.266460                      NaN
# 10                     Israel           3.088540                      NaN
# 11                 Costa Rica           3.177280                      NaN
# ...

# %%
combined.isnull().sum()
# Out:
# COUNTRY                           0
# DYSTOPIA RESIDUAL                 0
# ECONOMY  GDP PER CAPITA         315
# ECONOMY GDP PER CAPITA          155
# FAMILY                            0
# FREEDOM                           0
# GENEROSITY                        0
# HAPPINESS RANK                    0
# HAPPINESS SCORE                   0
# HEALTH  LIFE EXPECTANCY         315
# HEALTH LIFE EXPECTANCY          155
# LOWER CONFIDENCE INTERVAL       313
# REGION                          155
# STANDARD ERROR                  312
# TRUST  GOVERNMENT CORRUPTION    315
# TRUST GOVERNMENT CORRUPTION     155
# UPPER CONFIDENCE INTERVAL       313
# WHISKER HIGH                    315
# WHISKER LOW                     315
# YEAR                              0
# dtype: int64

# %%
missing=combined.set_index("YEAR").copy()
missing
# Out:
#                        COUNTRY  DYSTOPIA RESIDUAL  ECONOMY  GDP PER CAPITA  \
# YEAR
# 2015               Switzerland           2.517380                      NaN
# 2015                   Iceland           2.702010                      NaN
# 2015                   Denmark           2.492040                      NaN
# 2015                    Norway           2.465310                      NaN
# 2015                    Canada           2.451760                      NaN
# 2015                   Finland           2.619550                      NaN
# 2015               Netherlands           2.465700                      NaN
# 2015                    Sweden           2.371190                      NaN
# 2015               New Zealand           2.264250                      NaN
# 2015                 Australia           2.266460                      NaN
# 2015                    Israel           3.088540                      NaN
# ...

# %%
import seaborn as sns
sns.heatmap(missing.isnull())

# %%
#mishap15=hap15[["COUNTRY","REGION"]]
#mishap15
region15=pd.DataFrame({"COUNTRY":hap15["COUNTRY"],"REGION":hap15["REGION"]})
region15
# Out:
#                       COUNTRY                           REGION
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# 13                     Mexico      Latin America and Caribbean
# ...

# %%
region16=pd.DataFrame({"COUNTRY":hap16["COUNTRY"],"REGION":hap16["REGION"]})
region15
#mishap16=hap16[["COUNTRY","REGION"]]
#mishap16.sort_values(ascending=True)
# Out:
#                       COUNTRY                           REGION
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# 13                     Mexico      Latin America and Caribbean
# ...

# %%
regionmerged=pd.merge(left=region15,right=region16,on="COUNTRY",how="left")
regionmerged
# Out:
#                       COUNTRY                         REGION_x  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# 13                     Mexico      Latin America and Caribbean
# ...

# %%
regionmerged=pd.merge(left=region15,right=region16,on="COUNTRY",how="left")
regionmerged
# Out:
#                       COUNTRY                         REGION_x  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# 13                     Mexico      Latin America and Caribbean
# ...

# %%
regionmerged["REGION"]=regionmerged["REGION_x"]
regionmerged
# Out:
#                       COUNTRY                         REGION_x  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# 13                     Mexico      Latin America and Caribbean
# ...

# %%
regionmerged["REGION"].isnull().sum()
# Out:
# 0

# %%
regionmerged["REGION_y"].isnull().sum()
# Out:
# 7

# %%
regionmerged.loc[regionmerged["REGION"].isnull(),"REGION"]=regionmerged["REGION_y"]

# %%
regionmerged=regionmerged.drop(["REGION_x","REGION_y"],axis=1)

# %%
#regionmerged=pd.merge(left=region15,right=region16,on="COUNTRY",how="left")
regionmerged
# Out:
#                       COUNTRY                           REGION
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# 13                     Mexico      Latin America and Caribbean
# ...

# %%
regionmerged.columns
# Out:
# Index(['COUNTRY', 'REGION'], dtype='object')

# %%
combined=pd.merge(left=combined,right=regionmerged,on="COUNTRY",how="left")
combined
# Out:
#                       COUNTRY  DYSTOPIA RESIDUAL  ECONOMY  GDP PER CAPITA  \
# 0                 Switzerland           2.517380                      NaN
# 1                     Iceland           2.702010                      NaN
# 2                     Denmark           2.492040                      NaN
# 3                      Norway           2.465310                      NaN
# 4                      Canada           2.451760                      NaN
# 5                     Finland           2.619550                      NaN
# 6                 Netherlands           2.465700                      NaN
# 7                      Sweden           2.371190                      NaN
# 8                 New Zealand           2.264250                      NaN
# 9                   Australia           2.266460                      NaN
# 10                     Israel           3.088540                      NaN
# 11                 Costa Rica           3.177280                      NaN
# ...

# %%
combined.drop("REGION_y",axis=1,inplace=True)

# %%
combined["REGION"].isnull().sum
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'REGION'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-b033569623bd> in <module>
# ----> 1 combined["REGION"].isnull().sum
#
# ...

# %%
combined
# Out:
#                       COUNTRY  DYSTOPIA RESIDUAL  ECONOMY  GDP PER CAPITA  \
# 0                 Switzerland           2.517380                      NaN
# 1                     Iceland           2.702010                      NaN
# 2                     Denmark           2.492040                      NaN
# 3                      Norway           2.465310                      NaN
# 4                      Canada           2.451760                      NaN
# 5                     Finland           2.619550                      NaN
# 6                 Netherlands           2.465700                      NaN
# 7                      Sweden           2.371190                      NaN
# 8                 New Zealand           2.264250                      NaN
# 9                   Australia           2.266460                      NaN
# 10                     Israel           3.088540                      NaN
# 11                 Costa Rica           3.177280                      NaN
# ...

# %%
missing1=combined.set_index("YEAR").copy()
missing1
# Out:
#                        COUNTRY  DYSTOPIA RESIDUAL  ECONOMY  GDP PER CAPITA  \
# YEAR
# 2015               Switzerland           2.517380                      NaN
# 2015                   Iceland           2.702010                      NaN
# 2015                   Denmark           2.492040                      NaN
# 2015                    Norway           2.465310                      NaN
# 2015                    Canada           2.451760                      NaN
# 2015                   Finland           2.619550                      NaN
# 2015               Netherlands           2.465700                      NaN
# 2015                    Sweden           2.371190                      NaN
# 2015               New Zealand           2.264250                      NaN
# 2015                 Australia           2.266460                      NaN
# 2015                    Israel           3.088540                      NaN
# ...

# %%
sns.heatmap(missing1.isnull())

# %%
combined.duplicated().sum()
# Out:
# 0

# %%
combined["COUNTRY"]=combined["COUNTRY"].str.upper()

# %%
combined.duplicated(["COUNTRY","YEAR"])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 440    False
# 441    False
# 442    False
# 443    False
# 444    False
# 445    False
# 446    False
# 447    False
# 448    False
# 449    False
# 450    False
# 451    False
# 452    False
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# 458    False
# 459    False
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# 465    False
# 466    False
# 467    False
# 468    False
# 469    False
# Length: 470, dtype: bool

# %%
combined.duplicated().sum()
# Out:
# 0

# %%
combined[["COUNTRY","YEAR"]].duplicated()

# %%
#displays only rows where health life expectancy is null
abc = pd.isnull(combined["HEALTH LIFE EXPECTANCY"])
combined[abc]
# Out:
#                       COUNTRY  DYSTOPIA RESIDUAL  ECONOMY  GDP PER CAPITA  \
# 315                    NORWAY           2.277027                 1.616463
# 316                   DENMARK           2.313707                 1.482383
# 317                   ICELAND           2.322715                 1.480633
# 318               SWITZERLAND           2.276716                 1.564980
# 319                   FINLAND           2.430182                 1.443572
# 320               NETHERLANDS           2.294804                 1.503945
# 321                    CANADA           2.187264                 1.479204
# 322               NEW ZEALAND           2.046456                 1.405706
# 323                    SWEDEN           2.097538                 1.494387
# 324                 AUSTRALIA           2.065211                 1.484415
# 325                    ISRAEL           2.801757                 1.375382
# 326                COSTA RICA           2.898639                 1.109706
# ...
